# %% [markdown]
# # Proyecto empresa aliada: entregable 1
#
# ## Resumen:
#
#  Para realizar este proyecto primero importe los DataFrames y revise que no hubiese caracteres raros, saltos de linea o espacios vacios. Posteriormente comence a unir los DF usando columnas similares, Note que a pesar de que en varios DF se menciona la categoria, pero todos tenian el Valor "1", no pude desifrar si se podia deducir la categoria con algun otro atributo sin llegar a intentar "asumir o adivinar" que categoria era cada producto o segmento, por lo que pense que quiza era un error con alguno de los archivos.
#
# Para finalizar Elimine columnas que no me parecian relevantos o que estaban repetidas. Como resultado me quede con un DF que muestra toda la informacion relevante para poder sacar las ventas por determinado periodo, producto, segmento, fabricante y demas combinaciones.

# %%
import pandas as pd

#cargar archivos  XLSX y CSV
df_DIM_CALENDAR = pd.read_excel('DIM_CALENDAR.xlsx')
df_DIM_CATEGORY= pd.read_csv('DIM_CATEGORY.csv')
df_DIM_PRODUCT = pd.read_excel('DIM_PRODUCT.xlsx')
df_DIM_SEGMENT = pd.read_excel('DIM_SEGMENT.xlsx')
df_FACT_SALES = pd.read_csv('FACT_SALES.csv')

# %%
#confirmar que se cargaron correctamente con el metodo 

df_DIM_CALENDAR.info() # No se observa nada raro
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   WEEK         156 non-null    object
#  1   YEAR         156 non-null    int64
#  2   MONTH        156 non-null    int64
#  3   WEEK_NUMBER  156 non-null    int64
#  4   DATE         156 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 6.2+ KB

# %%
df_DIM_CATEGORY.info() # No se observa nada raro
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_CATEGORY  5 non-null      int64
#  1   CATEGORY     5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes

# %%
df_DIM_PRODUCT.info()# hay algunas columnas con valores 499 debo validar eso
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MANUFACTURER      505 non-null    object
#  1   BRAND             505 non-null    object
#  2   ITEM              503 non-null    object
#  3   ITEM_DESCRIPTION  505 non-null    object
#  4   CATEGORY          505 non-null    int64
#  5   FORMAT            505 non-null    object
#  6   ATTR1             499 non-null    object
#  7   ATTR2             505 non-null    object
#  8   ATTR3             499 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 35.6+ KB

# %%
df_DIM_SEGMENT.info() #ATTR3 tiene solo 52 en lugar de 53 valores
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CATEGORY  53 non-null     int64
#  1   ATTR1     53 non-null     object
#  2   ATTR2     53 non-null     object
#  3   ATTR3     52 non-null     object
#  4   FORMAT    53 non-null     object
#  5   SEGMENT   53 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.6+ KB

# %%
df_FACT_SALES.info() # No hay valores vacios
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122002 entries, 0 to 122001
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   WEEK                         122002 non-null  object
#  1   ITEM_CODE                    122002 non-null  object
#  2   TOTAL_UNIT_SALES             122002 non-null  float64
#  3   TOTAL_VALUE_SALES            122002 non-null  float64
#  4   TOTAL_UNIT_AVG_WEEKLY_SALES  122002 non-null  float64
#  5   REGION                       122002 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 5.6+ MB

# %% [markdown]
# # -----------INICIO DE LIMPIEZA DE FILES --------------

# %%
# uso el metodo .head() para ver si algo resalta a simple vista
#Hay un error en "FABRIC TREATMENT and SANIT\r\n" debe decir "FABRIC TREATMENT and SANIT"
df_DIM_CATEGORY.head(1)
# Out:
#    ID_CATEGORY                        CATEGORY
# 0            1  FABRIC TREATMENT and SANIT\r\n

# %%
df_DIM_CATEGORY['CATEGORY'] = df_DIM_CATEGORY['CATEGORY'].str.strip()
df_DIM_CATEGORY.head(1) #Salto de linea eliminado
# Out:
#    ID_CATEGORY                    CATEGORY
# 0            1  FABRIC TREATMENT and SANIT

# %%
df_DIM_PRODUCT.isna().sum()# Uso este metodo de .isna().sum() para buscar valores NaN
# Out:
# MANUFACTURER        0
# BRAND               0
# ITEM                2
# ITEM_DESCRIPTION    0
# CATEGORY            0
# FORMAT              0
# ATTR1               6
# ATTR2               0
# ATTR3               6
# dtype: int64

# %%
df_DIM_SEGMENT.isna().sum()
# Out:
# CATEGORY    0
# ATTR1       0
# ATTR2       0
# ATTR3       1
# FORMAT      0
# SEGMENT     0
# dtype: int64

# %%
df_DIM_PRODUCT['ATTR1'].value_counts(dropna=False) # use este metodo para validar los valores de cada columna y buscar NaN

#Asi puedo ver que no hay mezcla de mayusculas y minusculas o valores invalidos
# Out:
# ATTR1
# CLORO          243
# SAFE BLEACH    218
# PRELAVADOR      27
# SANITIZANTE     11
# NaN              6
# Name: count, dtype: int64

# %%
df_DIM_SEGMENT['ATTR3'] = df_DIM_SEGMENT['ATTR3'].fillna('NO DEFINIDO')# Cambio el valor NaN por 'NO DEFINIDO' para no dejar celdas vacias.

# %%
df_DIM_SEGMENT['ATTR3'].isna().value_counts()
# Out:
# ATTR3
# False    53
# Name: count, dtype: int64

# %%
#Me parece poco eficiente buscar columna por columna asi que investigue como implemetar un FOR-
#para buscar toda la tabla usando los metodos que ya habia implementado

for col in df_DIM_PRODUCT.columns:
    print(f"\nValores únicos en '{col}':")
    print(df_DIM_PRODUCT[col].value_counts(dropna=False))
    print("-" * 50)
# Out:
# Valores únicos en 'MANUFACTURER':
# MANUFACTURER
# RECKITT                     128
# INDS. ALEN                  127
# CLOROX                       94
# CHURCH & DWIGHT              31
# JABONERA LA ESPUMA           27
# DELTA PRONATURA              22
# OTHERS FABRICANTE UNIF.      21
# QUIMICA GONCAL               13
# BLANQUEADORA MEXICANA         9
# CLARASOL                      6
# SC JOHNSON                    5
# IBERIA                        5
# P&G                           4
# GRUPO AC MARCAS               3
# INDS. H24                     3
# FAB. DE JABON LA REINERA      2
# LA CORONA                     2
# WHITE MAGIC                   1
# LA JAPONESA                   1
# ARTIC WHITE                   1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'BRAND':
# BRAND
# CLORALEX                     115
# VANISH                       103
# CLOROX                        94
# OXI CLEAN                     31
# BANDERA                       25
# DR.BECKMANN                   22
# OTHERS MARCA UNIF.            21
# VANISH PODER 02               10
# BLANCATEL                     10
# LYSOL                          8
# CLORTEX                        8
# LOS PATITOS                    6
# CLARASOL                       6
# IBERIA                         5
# SHOUT                          5
# TIDE                           4
# VANISH CRYSTAL WHITE           4
# CUELLOS PUNOS Y MANCHITAS      3
# PATITO                         3
# SANYTOL                        3
# LA VALENCIANA                  3
# BCLORHADA                      2
# MARIPOSA                       2
# CLORO 10                       2
# HARPIC                         2
# VANISH EXTRA HIGIENE           1
# ARTIC WHITE                    1
# WHITE MAGIC                    1
# RADIANTE                       1
# LA JAPONESA                    1
# PURO SOL                       1
# CARISMA                        1
# CLORALUZ                       1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'ITEM':
# ITEM
# NaN                 2
# 0000075000592       1
# 7501058796950BP1    1
# 7501071901867       1
# 7501071901591       1
#                    ..
# 7501025406578       1
# 7501025406561       1
# 7501025405885       1
# 7501025405816       1
# 7502240948188BP1    1
# Name: count, Length: 504, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'ITEM_DESCRIPTION':
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000075000592                         1
# LYSOL LAUNDRYSANITIZERPOUCH500M+MMDESINFCRISPLINENLAT354GPVP 7501058797865BP2    1
# CLOROX MENTA FRESCA BOT.PLAS 3800ML NAL 7501071901874                            1
# CLOROX MENTA FRESCA BOT.PLAS 930ML NAL 7501071901867                             1
# CLOROX BLANQUEADOR PARAISO TROPICAL 3800 ML NAL 7501071901591                    1
#                                                                                 ..
# CLORALEX AROMAS BLAQUEADOR LIQUIDO FLORAL GAR 10LT 7501025408404                 1
# CLORALEX AROMA CLORO LIQUIDO LAVANDA BP 3.75L 7501025406578                      1
# CLORALEX AROMA CLORO LIQUIDO LAVANDA BP 2L 7501025406561                         1
# CLORALEX GEL ROPA BLANCA BP 950 ML 7501025405885                                 1
# CLOROX BLANQ930M+MMBLANQINOD709M+MMFIBRAULTRA1P+MMCUBETA1P 7502240948188BP1      1
# Name: count, Length: 505, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'CATEGORY':
# CATEGORY
# 1    505
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'FORMAT':
# FORMAT
# LIQUIDO    326
# POLVO       95
# GEL         72
# BARRA       11
# TOALLAS      1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'ATTR1':
# ATTR1
# CLORO          243
# SAFE BLEACH    218
# PRELAVADOR      27
# SANITIZANTE     11
# NaN              6
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'ATTR2':
# ATTR2
# CLORO               249
# FABRIC TREATMENT    245
# SANITIZANTE          11
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'ATTR3':
# ATTR3
# NO DEFINIDO            137
# PRE LAVADOR             85
# ROSA                    82
# OTR. TIPOS              55
# BLANCO                  50
# MULTIUSOS               41
# MASCOTAS                19
# SANITIZANTE             11
# ROPA COLOR               8
# NaN                      6
# ROPA BEBE                3
# COLOR PODER VINAGRE      2
# QUITAMANCHAS             2
# ROPA BLANCA              2
# GERMICIDA                1
# BAMBINO                  1
# Name: count, dtype: int64
# --------------------------------------------------

# %%
    #uso el mismo metodo para contar los NaN
for col in df_DIM_PRODUCT.columns:
        print(f"\nValores vacios en '{col}':")
        print(df_DIM_PRODUCT[col].isna().value_counts(dropna=False))
        print("-" * 50)
# Out:
# Valores vacios en 'MANUFACTURER':
# MANUFACTURER
# False    505
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'BRAND':
# BRAND
# False    505
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'ITEM':
# ITEM
# False    503
# True       2
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'ITEM_DESCRIPTION':
# ITEM_DESCRIPTION
# False    505
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'CATEGORY':
# CATEGORY
# False    505
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'FORMAT':
# FORMAT
# False    505
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'ATTR1':
# ATTR1
# False    499
# True       6
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'ATTR2':
# ATTR2
# False    505
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'ATTR3':
# ATTR3
# False    499
# True       6
# Name: count, dtype: int64
# --------------------------------------------------

# %%
#ITEM , ATTR1 y ATTR3 tienen valores vacios,los cambio a "NO DEFINIDO"
df_DIM_PRODUCT = df_DIM_PRODUCT.fillna('NO DEFINIDO')

# %%
for col in df_FACT_SALES.columns:
    print(f"\nValores únicos en '{col}':")
    print(df_FACT_SALES[col].value_counts(dropna=False))
    print("-" * 50)
# Out:
# Valores únicos en 'WEEK':
# WEEK
# 07-22    1629
# 14-22    1625
# 10-22    1622
# 09-22    1620
# 16-22    1619
#          ...
# 23-23    1442
# 26-23    1434
# 28-23    1433
# 25-23    1430
# 27-23    1429
# Name: count, Length: 80, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'ITEM_CODE':
# ITEM_CODE
# 7501025405106       560
# 7501025405885       560
# 4008455425412       560
# 7501025401849       560
# 7501025401856       560
#                    ...
# 7501025441326BP2      2
# 0616533000525         2
# 7501025402211         2
# 0123456808218         2
# 7501058716446         2
# Name: count, Length: 350, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'TOTAL_UNIT_SALES':
# TOTAL_UNIT_SALES
# 0.001     3755
# 0.002     2084
# 0.003     1583
# 0.004     1247
# 0.005     1169
#           ...
# 25.333       1
# 11.879       1
# 3.796        1
# 63.840       1
# 21.152       1
# Name: count, Length: 15197, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'TOTAL_VALUE_SALES':
# TOTAL_VALUE_SALES
# 0.023      230
# 0.021      208
# 0.020      192
# 0.010      143
# 0.128      136
#           ...
# 39.834       1
# 65.660       1
# 38.882       1
# 56.790       1
# 301.973      1
# Name: count, Length: 64425, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'TOTAL_UNIT_AVG_WEEKLY_SALES':
# TOTAL_UNIT_AVG_WEEKLY_SALES
# 1.000     5511
# 2.000     2493
# 3.000     1310
# 1.500     1151
# 4.000      801
#           ...
# 26.321       1
# 8.217        1
# 12.065       1
# 36.911       1
# 22.090       1
# Name: count, Length: 26662, dtype: int64
# --------------------------------------------------
#
# Valores únicos en 'REGION':
# REGION
# TOTAL AUTOS SCANNING MEXICO    20990
# TOTAL AUTOS AREA 2             18505
# TOTAL AUTOS AREA 4             17182
# TOTAL AUTOS AREA 6             16913
# TOTAL AUTOS AREA 3             16496
# TOTAL AUTOS AREA 5             16135
# TOTAL AUTOS AREA 1             15781
# Name: count, dtype: int64
# --------------------------------------------------

# %%
for col in df_FACT_SALES.columns:
        print(f"\nValores vacios en '{col}':")
        print(df_FACT_SALES[col].isna().value_counts(dropna=False))
        print("-" * 50)
# Out:
# Valores vacios en 'WEEK':
# WEEK
# False    122002
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'ITEM_CODE':
# ITEM_CODE
# False    122002
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'TOTAL_UNIT_SALES':
# TOTAL_UNIT_SALES
# False    122002
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'TOTAL_VALUE_SALES':
# TOTAL_VALUE_SALES
# False    122002
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'TOTAL_UNIT_AVG_WEEKLY_SALES':
# TOTAL_UNIT_AVG_WEEKLY_SALES
# False    122002
# Name: count, dtype: int64
# --------------------------------------------------
#
# Valores vacios en 'REGION':
# REGION
# False    122002
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# # ----------------FINAL DE LIMPIEZA DE DATOS ------------------------------

# %% [markdown]
# # ------ Unir los DataFrames ------
# ### df_DIM_CALENDAR
# ### df_DIM_CATEGORY
# ### df_DIM_PRODUCT
# ### df_DIM_SEGMENT
# ### df_FACT_SALES

# %% [markdown]
# Realiza uniones entre los DataFrames para consolidar la información.
# Por ejemplo, une la tabla de productos con las ventas, las categorías y los segmentos.

# %%
#df_DIM_PRODUCT y df_FACT_SALES---------------------------------------------

# %%
df_DIM_PRODUCT.head(1) # DERECHA*-*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-*-*-*
# Out:
#   MANUFACTURER     BRAND           ITEM  \
# 0   INDS. ALEN  CLORALEX  0000075000592
#
#                                     ITEM_DESCRIPTION  CATEGORY   FORMAT  \
# 0  CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 000...         1  LIQUIDO
#
#    ATTR1  ATTR2        ATTR3
# 0  CLORO  CLORO  NO DEFINIDO

# %%
df_DIM_PRODUCT['ITEM'].str.strip()
# Out:
# 0         0000075000592
# 1         0000075000608
# 2         0000075000615
# 3         0000075000622
# 4         0000075000639
#              ...
# 500    7501058789778BP1
# 501       7501025412142
# 502         NO DEFINIDO
# 503         NO DEFINIDO
# 504    7502240948188BP1
# Name: ITEM, Length: 505, dtype: object

# %%
df_FACT_SALES.head(1) #IZQUIERDA*-*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-*-*-*
# Out:
#     WEEK         ITEM_CODE  TOTAL_UNIT_SALES  TOTAL_VALUE_SALES  \
# 0  34-22  7501058792808BP2             0.006              0.139
#
#    TOTAL_UNIT_AVG_WEEKLY_SALES              REGION
# 0                          1.0  TOTAL AUTOS AREA 5

# %%
df_FACT_SALES['ITEM_CODE'].str.strip()
# Out:
# 0         7501058792808BP2
# 1            7501058715883
# 2            7702626213774
# 3            7501058716422
# 4            7501058784353
#                 ...
# 121997    7501058792778BP1
# 121998       7501058757630
# 121999       7501058753441
# 122000    7702626204208BP1
# 122001       7501058784346
# Name: ITEM_CODE, Length: 122002, dtype: object

# %%
#juntando los 2 Dataframes usando como referencia el ITEM e ITEM_CODE, dejando incluso los que no son iguales
#Para ver si hay algo que pueda checar despues. Dejo el indicador para filtrar 
df_SALES_PRODUCT = pd.merge(df_DIM_PRODUCT, df_FACT_SALES, left_on='ITEM', right_on='ITEM_CODE', how='left',indicator = True) 
df_SALES_PRODUCT =df_SALES_PRODUCT.set_index('ITEM_DESCRIPTION')
df_SALES_PRODUCT.shape
# Out:
# (122157, 15)

# %%
df_SALES_PRODUCT.head(5) #NUEVO DATAFRAME CON VENTAS Y PRODUCTOS
# Out:
#                                                    MANUFACTURER     BRAND  \
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...   INDS. ALEN  CLORALEX
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...   INDS. ALEN  CLORALEX
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...   INDS. ALEN  CLORALEX
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...   INDS. ALEN  CLORALEX
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...   INDS. ALEN  CLORALEX
#
#                                                              ITEM  CATEGORY  \
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  0000075000592         1
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  0000075000592         1
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  0000075000592         1
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  0000075000592         1
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  0000075000592         1
#
#                                                      FORMAT  ATTR1  ATTR2  \
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  LIQUIDO  CLORO  CLORO
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  LIQUIDO  CLORO  CLORO
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  LIQUIDO  CLORO  CLORO
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  LIQUIDO  CLORO  CLORO
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  LIQUIDO  CLORO  CLORO
#
#                                                           ATTR3   WEEK  \
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  NO DEFINIDO  45-22
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  NO DEFINIDO  48-22
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  NO DEFINIDO  03-22
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  NO DEFINIDO  05-22
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  NO DEFINIDO  09-22
#
#                                                         ITEM_CODE  \
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  0000075000592
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  0000075000592
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  0000075000592
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  0000075000592
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  0000075000592
#
#                                                     TOTAL_UNIT_SALES  \
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...             0.034
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...             0.002
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...             0.432
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...             0.233
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...             0.055
#
#                                                     TOTAL_VALUE_SALES  \
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...              0.142
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...              0.009
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...              1.956
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...              0.779
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...              0.251
#
#                                                     TOTAL_UNIT_AVG_WEEKLY_SALES  \
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...                        8.500
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...                        1.000
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...                       14.400
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...                       11.095
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...                        5.500
#
#                                                                          REGION  \
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  TOTAL AUTOS SCANNING MEXICO
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  TOTAL AUTOS SCANNING MEXICO
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  TOTAL AUTOS SCANNING MEXICO
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  TOTAL AUTOS SCANNING MEXICO
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...  TOTAL AUTOS SCANNING MEXICO
#
#                                                    _merge
# ITEM_DESCRIPTION
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...   both
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...   both
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...   both
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...   both
# CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 0000...   both

# %%
df_SALES_PRODUCT_NaN = df_SALES_PRODUCT[df_SALES_PRODUCT['_merge'] != 'both']
df_SALES_PRODUCT_NaN.shape
#Encontre lineas con informacion faltante
# Out:
# (155, 15)

# %%
df_SALES_PRODUCT_NaN.head(1)
# Out:
#                                                    MANUFACTURER     BRAND  \
# ITEM_DESCRIPTION
# CLORALEX FANTASIA FLORAL BOT PLAST 950ML NAL 00...   INDS. ALEN  CLORALEX
#
#                                                              ITEM  CATEGORY  \
# ITEM_DESCRIPTION
# CLORALEX FANTASIA FLORAL BOT PLAST 950ML NAL 00...  0000075000646         1
#
#                                                      FORMAT  ATTR1  ATTR2  \
# ITEM_DESCRIPTION
# CLORALEX FANTASIA FLORAL BOT PLAST 950ML NAL 00...  LIQUIDO  CLORO  CLORO
#
#                                                          ATTR3 WEEK ITEM_CODE  \
# ITEM_DESCRIPTION
# CLORALEX FANTASIA FLORAL BOT PLAST 950ML NAL 00...  OTR. TIPOS  NaN       NaN
#
#                                                     TOTAL_UNIT_SALES  \
# ITEM_DESCRIPTION
# CLORALEX FANTASIA FLORAL BOT PLAST 950ML NAL 00...               NaN
#
#                                                     TOTAL_VALUE_SALES  \
# ITEM_DESCRIPTION
# CLORALEX FANTASIA FLORAL BOT PLAST 950ML NAL 00...                NaN
#
#                                                     TOTAL_UNIT_AVG_WEEKLY_SALES  \
# ITEM_DESCRIPTION
# CLORALEX FANTASIA FLORAL BOT PLAST 950ML NAL 00...                          NaN
#
#                                                    REGION     _merge
# ITEM_DESCRIPTION
# CLORALEX FANTASIA FLORAL BOT PLAST 950ML NAL 00...    NaN  left_only

# %%
#No puedo hacer nada con estos productos. no veo caracteres de mas o espcios
#parece que solo son Items que no se vendieron entre las de las semanas de año registradas
df_SALES_PRODUCT_NaN['ITEM'].value_counts()
# Out:
# ITEM
# NO DEFINIDO         2
# 7501058791658BP1    1
# 7501058789365       1
# 7501058790422BP1    1
# 7501058790705BP2    1
#                    ..
# 7501025441319BP2    1
# 7501025441357BP1    1
# 7501025441463BP2    1
# 7501025450274       1
# 7501058757647       1
# Name: count, Length: 154, dtype: int64

# %%
# Voy a dejar el DataFrame sin las lineas vacias. 

df_SALES_PRODUCT = pd.merge(df_DIM_PRODUCT, df_FACT_SALES, left_on='ITEM', right_on='ITEM_CODE', how='inner') 



df_SALES_PRODUCT.shape#NUEVO DATAFRAME CON VENTAS Y PRODUCTOS*-*-*-*-*-*-*-*-*-*
# Out:
# (122002, 15)

# %%
#df_DIM_CATEGORY y df_DIM_SEGMENT --------------------------------------------------------
#Pensaba unir Datafrmes usando el ID_CATEGORY, pero todos los archivosque hacen refererencia a categoria tienen "1". 
#Se asume que hay un error con el archivo ya que no puedo asumir la categoria sin mas informacion.
#Las columnas ATTR1, 2 y 3 estan en mi nuevo DataFrame de productos y ventas. los puedo usar para identificar el segmento.

# %%
df_DIM_CATEGORY.head(1)
# Out:
#    ID_CATEGORY                    CATEGORY
# 0            1  FABRIC TREATMENT and SANIT

# %%
df_DIM_SEGMENT.head(1)
# Out:
#    CATEGORY  ATTR1  ATTR2    ATTR3   FORMAT SEGMENT
# 0         1  CLORO  CLORO  BAMBINO  LIQUIDO  BLEACH

# %%
#Unir Segmento con ventas y productos. 
df_SALES_PRODUCT_SEGMENT = pd.merge(df_SALES_PRODUCT, df_DIM_SEGMENT, on= ['ATTR1', 'ATTR2', 'ATTR3','FORMAT'], how='left')




df_SALES_PRODUCT_SEGMENT ['SEGMENT'].value_counts() #NUEVO DATA FRAME CON VENTAS, PRODUCTOS Y SEGMENTO
# Out:
# SEGMENT
# BLEACH          83646
# LIQUID & GEL    22697
# PRETREAT        19143
# POWDER          17694
# SANITIZER        5023
# BAR              3639
# OTHERS            560
# Name: count, dtype: int64

# %%
df_SALES_PRODUCT_SEGMENT.isna().any().sum() #checando que no tenga valores vacios
# Out:
# 0

# %%
df_SALES_PRODUCT_SEGMENT.head(1)
# Out:
#   MANUFACTURER     BRAND           ITEM  \
# 0   INDS. ALEN  CLORALEX  0000075000592
#
#                                     ITEM_DESCRIPTION  CATEGORY_x   FORMAT  \
# 0  CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 000...           1  LIQUIDO
#
#    ATTR1  ATTR2        ATTR3   WEEK      ITEM_CODE  TOTAL_UNIT_SALES  \
# 0  CLORO  CLORO  NO DEFINIDO  45-22  0000075000592             0.034
#
#    TOTAL_VALUE_SALES  TOTAL_UNIT_AVG_WEEKLY_SALES  \
# 0              0.142                          8.5
#
#                         REGION  CATEGORY_y SEGMENT
# 0  TOTAL AUTOS SCANNING MEXICO           1  BLEACH

# %%
#df_DIM_CALENDAR con el DataFrame principal
#Voy a unir la informacion de la semana de los 2 dataframes
df_DIM_CALENDAR.head(1)
# Out:
#     WEEK  YEAR  MONTH  WEEK_NUMBER       DATE
# 0  01-21  2021      1            1 2021-01-10

# %%
df_SALES_PRODUCT_SEGMENT_DATE = pd.merge(df_SALES_PRODUCT_SEGMENT, df_DIM_CALENDAR, on= ['WEEK'], how='left')
df_SALES_PRODUCT_SEGMENT_DATE.isna().any().sum()
# Out:
# 0

# %%
df_SALES_PRODUCT_SEGMENT_DATE.head(1)
# Out:
#   MANUFACTURER     BRAND           ITEM  \
# 0   INDS. ALEN  CLORALEX  0000075000592
#
#                                     ITEM_DESCRIPTION  CATEGORY_x   FORMAT  \
# 0  CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 000...           1  LIQUIDO
#
#    ATTR1  ATTR2        ATTR3   WEEK  ... TOTAL_UNIT_SALES  TOTAL_VALUE_SALES  \
# 0  CLORO  CLORO  NO DEFINIDO  45-22  ...            0.034              0.142
#
#    TOTAL_UNIT_AVG_WEEKLY_SALES                       REGION CATEGORY_y  \
# 0                          8.5  TOTAL AUTOS SCANNING MEXICO          1
#
#    SEGMENT  YEAR  MONTH  WEEK_NUMBER       DATE
# 0   BLEACH  2022     11           45 2022-11-13
#
# [1 rows x 21 columns]

# %%
df_SALES_PRODUCT_SEGMENT_DATE.columns
# Out:
# Index(['MANUFACTURER', 'BRAND', 'ITEM', 'ITEM_DESCRIPTION', 'CATEGORY_x',
#        'FORMAT', 'ATTR1', 'ATTR2', 'ATTR3', 'WEEK', 'ITEM_CODE',
#        'TOTAL_UNIT_SALES', 'TOTAL_VALUE_SALES', 'TOTAL_UNIT_AVG_WEEKLY_SALES',
#        'REGION', 'CATEGORY_y', 'SEGMENT', 'YEAR', 'MONTH', 'WEEK_NUMBER',
#        'DATE'],
#       dtype='object')

# %% [markdown]
# # ------LIMPIAR DATAFRAME CONSOLIDADO ------

# %%
#Quitar columnas duplicadas o que no se usan
df_consolidado = df_SALES_PRODUCT_SEGMENT_DATE.drop(columns=['CATEGORY_y','ITEM_CODE','CATEGORY_x','WEEK'])

# %%
#Reorganizar DataFrame
column_consolidado = [
    'MANUFACTURER', 'BRAND', 'ITEM', 'ITEM_DESCRIPTION', 'FORMAT',
    'ATTR1', 'ATTR2', 'ATTR3','REGION', 'SEGMENT', 'YEAR', 'MONTH',
    'WEEK_NUMBER', 'DATE', 'TOTAL_UNIT_SALES', 'TOTAL_VALUE_SALES',
    'TOTAL_UNIT_AVG_WEEKLY_SALES'
]

# %%
df_consolidado = df_consolidado[column_consolidado]

# %%
#Cambiar index
df_consolidado = df_consolidado.set_index('ITEM')
df_consolidado["ITEM_DESCRIPTION"] = df_consolidado["ITEM_DESCRIPTION"].str.slice(stop=-13)

# %%
df_consolidado.to_csv('df_consolidado.csv', index=True) #DATAFRAME CONSOLIDADO

# %%
df_consolidado.head()
# Out:
#               MANUFACTURER     BRAND  \
# ITEM
# 0000075000592   INDS. ALEN  CLORALEX
# 0000075000592   INDS. ALEN  CLORALEX
# 0000075000592   INDS. ALEN  CLORALEX
# 0000075000592   INDS. ALEN  CLORALEX
# 0000075000592   INDS. ALEN  CLORALEX
#
#                                           ITEM_DESCRIPTION   FORMAT  ATTR1  \
# ITEM
# 0000075000592  CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL.   LIQUIDO  CLORO
# 0000075000592  CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL.   LIQUIDO  CLORO
# 0000075000592  CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL.   LIQUIDO  CLORO
# 0000075000592  CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL.   LIQUIDO  CLORO
# 0000075000592  CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL.   LIQUIDO  CLORO
#
#                ATTR2        ATTR3                       REGION SEGMENT  YEAR  \
# ITEM
# 0000075000592  CLORO  NO DEFINIDO  TOTAL AUTOS SCANNING MEXICO  BLEACH  2022
# 0000075000592  CLORO  NO DEFINIDO  TOTAL AUTOS SCANNING MEXICO  BLEACH  2022
# 0000075000592  CLORO  NO DEFINIDO  TOTAL AUTOS SCANNING MEXICO  BLEACH  2022
# 0000075000592  CLORO  NO DEFINIDO  TOTAL AUTOS SCANNING MEXICO  BLEACH  2022
# 0000075000592  CLORO  NO DEFINIDO  TOTAL AUTOS SCANNING MEXICO  BLEACH  2022
#
#                MONTH  WEEK_NUMBER       DATE  TOTAL_UNIT_SALES  \
# ITEM
# 0000075000592     11           45 2022-11-13             0.034
# 0000075000592     11           45 2022-11-13             0.034
# 0000075000592     12           48 2022-12-04             0.002
# 0000075000592     12           48 2022-12-04             0.002
# 0000075000592      1            3 2022-01-23             0.432
#
#                TOTAL_VALUE_SALES  TOTAL_UNIT_AVG_WEEKLY_SALES
# ITEM
# 0000075000592              0.142                          8.5
# 0000075000592              0.142                          8.5
# 0000075000592              0.009                          1.0
# 0000075000592              0.009                          1.0
# 0000075000592              1.956                         14.4
